# %% [markdown]
# <h1 style = "font-family:'Arial Narrow';font-size:4rem;color:darkblue;">Weather Py</h1>

# %% [markdown]
# Python script to visualize the weather of over 500 cities of varying distances from the equator.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import json
from scipy.stats import linregress

# %%
# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# <h2 style = "font-family:'Arial Narrow';font-size:2.5rem;color:Darkgrey;">Generate the Cities List by Using the "citipy" Library</h2>

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# print(json.dumps(cities, indent = 3, sort_keys = True))
# Out:
# Number of cities in the list: 594

# %% [markdown]
# <h2 style = "font-family:'Arial Narrow';font-size:2.5rem;color:Darkgrey;">Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude</h2>

# %%
# To fulfill the first requirement, you'll use the OpenWeatherMap API to retrieve weather data from the cities list generated in the starter code. 

# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Create endpoint URL with each city
    city_url = url +  city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() 

       # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | wailua homesteads
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | bubaque
# Processing Record 5 of Set 1 | west island
# Processing Record 6 of Set 1 | constantia
# Processing Record 7 of Set 1 | fort bragg
# Processing Record 8 of Set 1 | stanley
# Processing Record 9 of Set 1 | harper
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 12 of Set 1 | nieuw amsterdam
# Processing Record 13 of Set 1 | aioun
# Processing Record 14 of Set 1 | blackmans bay
# Processing Record 15 of Set 1 | whakatane
# Processing Record 16 of Set 1 | ulaangom
# Processing Record 17 of Set 1 | kampung sungai ara
# Processing Record 18 of Set 1 | laguna
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | nuevitas
# Processing Record 22 of Set 1 | malango
# Processing Record 23 of Set 1 | enewetak
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | rawson
# Processing Record 26 of Set 1 | genoa
# Processing Record 27 of Set 1 | isafjordur
# Processing Record 28 of Set 1 | badger
# Processing Record 29 of Set 1 | crane
# Processing Record 30 of Set 1 | mount isa
# Processing Record 31 of Set 1 | minas de marcona
# Processing Record 32 of Set 1 | sao jose da coroa grande
# Processing Record 33 of Set 1 | sur
# Processing Record 34 of Set 1 | aasiaat
# Processing Record 35 of Set 1 | sao vicente
# Processing Record 36 of Set 1 | brandfort
# Processing Record 37 of Set 1 | utrik
# Processing Record 38 of Set 1 | saipan
# Processing Record 39 of Set 1 | dayapar
# City not found. Skipping...
# Processing Record 40 of Set 1 | zalingei
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | santa marta
# Processing Record 44 of Set 1 | bilibino
# Processing Record 45 of Set 1 | illizi
# Processing Record 46 of Set 1 | papatowai
# Processing Record 47 of Set 1 | colachel
# Processing Record 48 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | elverum
# Processing Record 0 of Set 2 | nahiyat ash shinafiyah
# Processing Record 1 of Set 2 | sorong
# Processing Record 2 of Set 2 | island harbour
# Processing Record 3 of Set 2 | mil'kovo
# Processing Record 4 of Set 2 | edinburgh of the seven seas
# Processing Record 5 of Set 2 | sitka
# Processing Record 6 of Set 2 | saint-pierre
# Processing Record 7 of Set 2 | bull savanna
# Processing Record 8 of Set 2 | villamontes
# Processing Record 9 of Set 2 | fort st. john
# Processing Record 10 of Set 2 | grytviken
# Processing Record 11 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 12 of Set 2 | pacific grove
# Processing Record 13 of Set 2 | carutapera
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | pudozh
# Processing Record 16 of Set 2 | qaqortoq
# Processing Record 17 of Set 2 | invercargill
# Processing Record 18 of Set 2 | kulhudhuffushi
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | colac
# Processing Record 23 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 24 of Set 2 | qamdo
# Processing Record 25 of Set 2 | nuuk
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | safford
# Processing Record 29 of Set 2 | conduaga
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | tofol
# Processing Record 32 of Set 2 | kangding
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | vorkuta
# Processing Record 35 of Set 2 | straznice
# Processing Record 36 of Set 2 | yaiza
# Processing Record 37 of Set 2 | northam
# Processing Record 38 of Set 2 | beylikova
# Processing Record 39 of Set 2 | devils lake
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | tolanaro
# Processing Record 42 of Set 2 | bardai
# Processing Record 43 of Set 2 | castillos
# Processing Record 44 of Set 2 | fauske
# Processing Record 45 of Set 2 | remire-montjoly
# Processing Record 46 of Set 2 | chui
# Processing Record 47 of Set 2 | cativa
# Processing Record 48 of Set 2 | megion
# Processing Record 49 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 0 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 3 | labrador city
# Processing Record 3 of Set 3 | purranque
# Processing Record 4 of Set 3 | ushuaia
# Processing Record 5 of Set 3 | azadshahr
# Processing Record 6 of Set 3 | semey
# Processing Record 7 of Set 3 | tsiombe
# Processing Record 8 of Set 3 | puerto natales
# Processing Record 9 of Set 3 | carnot
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | mbekenyera
# Processing Record 12 of Set 3 | uruzgan
# Processing Record 13 of Set 3 | puerto leguizamo
# Processing Record 14 of Set 3 | goondiwindi
# Processing Record 15 of Set 3 | cherepovets
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | verkhnevilyuysk
# Processing Record 20 of Set 3 | puerto madero
# Processing Record 21 of Set 3 | sisimiut
# Processing Record 22 of Set 3 | whitehorse
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | adrar
# Processing Record 25 of Set 3 | namibe
# Processing Record 26 of Set 3 | haiku-pauwela
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | vanimo
# Processing Record 29 of Set 3 | wenchang
# Processing Record 30 of Set 3 | cozumel
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | midvagur
# Processing Record 33 of Set 3 | villa gesell
# Processing Record 34 of Set 3 | mandalgovi
# Processing Record 35 of Set 3 | manturovo
# Processing Record 36 of Set 3 | okhotsk
# Processing Record 37 of Set 3 | bhamo
# Processing Record 38 of Set 3 | severoural'sk
# Processing Record 39 of Set 3 | port mathurin
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | portage la prairie
# Processing Record 42 of Set 3 | casas grandes
# Processing Record 43 of Set 3 | dudinka
# Processing Record 44 of Set 3 | gueltat zemmour
# City not found. Skipping...
# Processing Record 45 of Set 3 | ust-nera
# Processing Record 46 of Set 3 | pandan
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | adh dhibiyah
# City not found. Skipping...
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 0 of Set 4 | saldanha
# Processing Record 1 of Set 4 | back mountain
# Processing Record 2 of Set 4 | bhimunipatnam
# Processing Record 3 of Set 4 | coahuayana de hidalgo
# Processing Record 4 of Set 4 | richards bay
# Processing Record 5 of Set 4 | klyuchi
# Processing Record 6 of Set 4 | turbat
# Processing Record 7 of Set 4 | keflavik
# Processing Record 8 of Set 4 | jaisalmer
# Processing Record 9 of Set 4 | hawaiian paradise park
# Processing Record 10 of Set 4 | taiyuan
# Processing Record 11 of Set 4 | manoharpur
# Processing Record 12 of Set 4 | sinop
# Processing Record 13 of Set 4 | zeya
# Processing Record 14 of Set 4 | flying fish cove
# Processing Record 15 of Set 4 | malinyi
# Processing Record 16 of Set 4 | chongwe
# Processing Record 17 of Set 4 | trujillo
# Processing Record 18 of Set 4 | pyu
# Processing Record 19 of Set 4 | aykol
# City not found. Skipping...
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | spencer
# Processing Record 22 of Set 4 | kurumul
# City not found. Skipping...
# Processing Record 23 of Set 4 | carauari
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | sile
# Processing Record 26 of Set 4 | nasrullahganj
# Processing Record 27 of Set 4 | kailua-kona
# Processing Record 28 of Set 4 | ad dilam
# Processing Record 29 of Set 4 | princeville
# Processing Record 30 of Set 4 | lihue
# Processing Record 31 of Set 4 | barcelos
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | altai
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | uturoa
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | punta arenas
# Processing Record 38 of Set 4 | avarua
# Processing Record 39 of Set 4 | bayan nur
# City not found. Skipping...
# Processing Record 40 of Set 4 | iskateley
# Processing Record 41 of Set 4 | bridgewater
# Processing Record 42 of Set 4 | porto novo
# Processing Record 43 of Set 4 | nioki
# Processing Record 44 of Set 4 | bikenibeu village
# Processing Record 45 of Set 4 | bitkine
# Processing Record 46 of Set 4 | north bend
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | talara
# Processing Record 49 of Set 4 | micheweni
# Processing Record 0 of Set 5 | chu
# Processing Record 1 of Set 5 | mili
# Processing Record 2 of Set 5 | wolfach
# Processing Record 3 of Set 5 | aksuat
# Processing Record 4 of Set 5 | weihai
# Processing Record 5 of Set 5 | alindao
# Processing Record 6 of Set 5 | brits
# Processing Record 7 of Set 5 | udachny
# Processing Record 8 of Set 5 | olonkinbyen
# Processing Record 9 of Set 5 | kalix
# Processing Record 10 of Set 5 | el sauzal de rodriguez
# Processing Record 11 of Set 5 | luganville
# Processing Record 12 of Set 5 | nizhneangarsk
# Processing Record 13 of Set 5 | wesley chapel
# Processing Record 14 of Set 5 | maceio
# Processing Record 15 of Set 5 | la passe
# Processing Record 16 of Set 5 | pemba
# Processing Record 17 of Set 5 | ancud
# Processing Record 18 of Set 5 | margaret river
# Processing Record 19 of Set 5 | praia da vitoria
# Processing Record 20 of Set 5 | novyy urgal
# Processing Record 21 of Set 5 | taos
# Processing Record 22 of Set 5 | manokwari
# Processing Record 23 of Set 5 | saint-joseph
# Processing Record 24 of Set 5 | port moresby
# Processing Record 25 of Set 5 | wattegama
# Processing Record 26 of Set 5 | nephi
# Processing Record 27 of Set 5 | sault ste. marie
# Processing Record 28 of Set 5 | el granada
# Processing Record 29 of Set 5 | phalaborwa
# Processing Record 30 of Set 5 | cidreira
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | balsas
# Processing Record 33 of Set 5 | okha
# Processing Record 34 of Set 5 | kodinsk
# Processing Record 35 of Set 5 | san isidro de curuguaty
# Processing Record 36 of Set 5 | vila franca do campo
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | nar'yan-mar
# Processing Record 39 of Set 5 | gadzhiyevo
# Processing Record 40 of Set 5 | jinshi
# Processing Record 41 of Set 5 | monroe
# Processing Record 42 of Set 5 | ha'il
# Processing Record 43 of Set 5 | kristiansund
# Processing Record 44 of Set 5 | bela
# Processing Record 45 of Set 5 | ilhabela
# Processing Record 46 of Set 5 | zouerate
# Processing Record 47 of Set 5 | afaahiti
# Processing Record 48 of Set 5 | slavyanka
# Processing Record 49 of Set 5 | naryn
# Processing Record 0 of Set 6 | zuromin
# Processing Record 1 of Set 6 | opuwo
# Processing Record 2 of Set 6 | ola
# Processing Record 3 of Set 6 | sogndal
# Processing Record 4 of Set 6 | berbera
# Processing Record 5 of Set 6 | chibougamau
# Processing Record 6 of Set 6 | tinaquillo
# Processing Record 7 of Set 6 | swift current
# Processing Record 8 of Set 6 | quellon
# Processing Record 9 of Set 6 | oliver
# Processing Record 10 of Set 6 | kembe
# Processing Record 11 of Set 6 | robbah
# Processing Record 12 of Set 6 | guapore
# Processing Record 13 of Set 6 | takamaka
# City not found. Skipping...
# Processing Record 14 of Set 6 | port alfred
# Processing Record 15 of Set 6 | ishikawa
# Processing Record 16 of Set 6 | bonga
# Processing Record 17 of Set 6 | ebaye
# Processing Record 18 of Set 6 | aromashevo
# Processing Record 19 of Set 6 | la gi
# Processing Record 20 of Set 6 | perm
# Processing Record 21 of Set 6 | tazovsky
# Processing Record 22 of Set 6 | city of balikpapan
# Processing Record 23 of Set 6 | port augusta
# Processing Record 24 of Set 6 | tome acu
# Processing Record 25 of Set 6 | mao
# Processing Record 26 of Set 6 | tieli
# Processing Record 27 of Set 6 | susuman
# Processing Record 28 of Set 6 | fredericton
# Processing Record 29 of Set 6 | tilisarao
# Processing Record 30 of Set 6 | yichang
# Processing Record 31 of Set 6 | bouarfa
# Processing Record 32 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 6 | vorgashor
# Processing Record 34 of Set 6 | karangsembung
# Processing Record 35 of Set 6 | sinabang
# Processing Record 36 of Set 6 | cidade velha
# Processing Record 37 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 38 of Set 6 | dhidhdhoo
# Processing Record 39 of Set 6 | kone
# Processing Record 40 of Set 6 | ust'-ilimsk
# Processing Record 41 of Set 6 | yukhary-dashkesan
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | gobabis
# Processing Record 44 of Set 6 | bikin
# Processing Record 45 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 46 of Set 6 | kapuskasing
# Processing Record 47 of Set 6 | tocache
# Processing Record 48 of Set 6 | fale old settlement
# Processing Record 49 of Set 6 | torrington
# Processing Record 0 of Set 7 | nema
# Processing Record 1 of Set 7 | quartu sant'elena
# Processing Record 2 of Set 7 | vilyuchinsk
# Processing Record 3 of Set 7 | as sulayyil
# Processing Record 4 of Set 7 | puerto lempira
# Processing Record 5 of Set 7 | jinjiang
# Processing Record 6 of Set 7 | nantucket
# Processing Record 7 of Set 7 | batangafo
# Processing Record 8 of Set 7 | maumere
# Processing Record 9 of Set 7 | cuttack
# Processing Record 10 of Set 7 | melfort
# Processing Record 11 of Set 7 | weno
# Processing Record 12 of Set 7 | parauapebas
# Processing Record 13 of Set 7 | severo-yeniseyskiy
# Processing Record 14 of Set 7 | puerto baquerizo moreno
# Processing Record 15 of Set 7 | dalton in furness
# Processing Record 16 of Set 7 | takedamachi
# Processing Record 17 of Set 7 | al kharijah
# Processing Record 18 of Set 7 | yanji
# Processing Record 19 of Set 7 | wotho
# Processing Record 20 of Set 7 | cockburn town
# Processing Record 21 of Set 7 | apostolove
# Processing Record 22 of Set 7 | agat village
# Processing Record 23 of Set 7 | arauca
# Processing Record 24 of Set 7 | happy valley-goose bay
# Processing Record 25 of Set 7 | santa ana hueytlalpan
# Processing Record 26 of Set 7 | colonia
# Processing Record 27 of Set 7 | hammerfest
# Processing Record 28 of Set 7 | mabaruma
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | taksimo
# Processing Record 31 of Set 7 | kiunga
# Processing Record 32 of Set 7 | oranjemund
# Processing Record 33 of Set 7 | cestos city
# Processing Record 34 of Set 7 | jamestown
# Processing Record 35 of Set 7 | hobyo
# Processing Record 36 of Set 7 | senges
# Processing Record 37 of Set 7 | siwa oasis
# Processing Record 38 of Set 7 | conceicao da barra
# Processing Record 39 of Set 7 | ponta delgada
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | zangguy
# City not found. Skipping...
# Processing Record 42 of Set 7 | kamloops
# Processing Record 43 of Set 7 | alice springs
# Processing Record 44 of Set 7 | khandyga
# Processing Record 45 of Set 7 | saint-philippe
# Processing Record 46 of Set 7 | argostolion
# Processing Record 47 of Set 7 | mount pearl
# Processing Record 48 of Set 7 | beykonak
# Processing Record 49 of Set 7 | mukalla
# Processing Record 0 of Set 8 | gebeit
# Processing Record 1 of Set 8 | dali
# Processing Record 2 of Set 8 | onega
# Processing Record 3 of Set 8 | dewa
# Processing Record 4 of Set 8 | kreminna
# Processing Record 5 of Set 8 | hotan
# Processing Record 6 of Set 8 | tazacorte
# Processing Record 7 of Set 8 | san juan
# Processing Record 8 of Set 8 | port-gentil
# Processing Record 9 of Set 8 | urengoy
# Processing Record 10 of Set 8 | ketchikan
# Processing Record 11 of Set 8 | bossangoa
# Processing Record 12 of Set 8 | nyurba
# Processing Record 13 of Set 8 | kovalam
# Processing Record 14 of Set 8 | hilo
# Processing Record 15 of Set 8 | howard springs
# Processing Record 16 of Set 8 | kimbe
# Processing Record 17 of Set 8 | holualoa
# Processing Record 18 of Set 8 | satun
# Processing Record 19 of Set 8 | prado
# Processing Record 20 of Set 8 | kerikeri
# Processing Record 21 of Set 8 | santa elena de uairen
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | alaghsas
# Processing Record 24 of Set 8 | guiuan
# Processing Record 25 of Set 8 | taltal
# Processing Record 26 of Set 8 | glace bay
# Processing Record 27 of Set 8 | munduk
# Processing Record 28 of Set 8 | kashgar
# Processing Record 29 of Set 8 | thinadhoo
# Processing Record 30 of Set 8 | naivasha
# Processing Record 31 of Set 8 | san-pedro
# Processing Record 32 of Set 8 | haimen
# Processing Record 33 of Set 8 | gizo
# Processing Record 34 of Set 8 | kuraymah
# Processing Record 35 of Set 8 | santa rosa
# Processing Record 36 of Set 8 | tura
# Processing Record 37 of Set 8 | worland
# Processing Record 38 of Set 8 | nelson bay
# Processing Record 39 of Set 8 | east ballina
# Processing Record 40 of Set 8 | cuite
# Processing Record 41 of Set 8 | morinville
# Processing Record 42 of Set 8 | smithers
# Processing Record 43 of Set 8 | nishinoomote
# Processing Record 44 of Set 8 | poso
# Processing Record 45 of Set 8 | vilyuysk
# Processing Record 46 of Set 8 | broome
# Processing Record 47 of Set 8 | lompoc
# Processing Record 48 of Set 8 | belmonte
# Processing Record 49 of Set 8 | ouellah
# City not found. Skipping...
# Processing Record 0 of Set 9 | ghanzi
# Processing Record 1 of Set 9 | jericho
# Processing Record 2 of Set 9 | itamaraca
# Processing Record 3 of Set 9 | pumiao
# Processing Record 4 of Set 9 | cartagena del chaira
# Processing Record 5 of Set 9 | anabar
# City not found. Skipping...
# Processing Record 6 of Set 9 | whangarei
# Processing Record 7 of Set 9 | buka
# Processing Record 8 of Set 9 | bengkulu
# Processing Record 9 of Set 9 | svetlyy
# Processing Record 10 of Set 9 | st. john's
# Processing Record 11 of Set 9 | skiathos
# Processing Record 12 of Set 9 | altay
# Processing Record 13 of Set 9 | golfito
# Processing Record 14 of Set 9 | rurrenabaque
# Processing Record 15 of Set 9 | ghadamis
# Processing Record 16 of Set 9 | barauna
# Processing Record 17 of Set 9 | north battleford
# Processing Record 18 of Set 9 | camiri
# Processing Record 19 of Set 9 | rikaze
# Processing Record 20 of Set 9 | itapuranga
# Processing Record 21 of Set 9 | new norfolk
# Processing Record 22 of Set 9 | kushiro
# Processing Record 23 of Set 9 | rio grande
# Processing Record 24 of Set 9 | izluchinsk
# Processing Record 25 of Set 9 | tucumcari
# Processing Record 26 of Set 9 | usinsk
# Processing Record 27 of Set 9 | yingkou
# Processing Record 28 of Set 9 | praya
# Processing Record 29 of Set 9 | atafu village
# Processing Record 30 of Set 9 | szczytno
# Processing Record 31 of Set 9 | horta
# Processing Record 32 of Set 9 | federacion
# Processing Record 33 of Set 9 | priob'ye
# Processing Record 34 of Set 9 | ojai
# Processing Record 35 of Set 9 | labytnangi
# Processing Record 36 of Set 9 | mejit
# Processing Record 37 of Set 9 | itoman
# Processing Record 38 of Set 9 | punta del este
# Processing Record 39 of Set 9 | codrington
# Processing Record 40 of Set 9 | aceuchal
# Processing Record 41 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 42 of Set 9 | wakkanai
# Processing Record 43 of Set 9 | broken hill
# Processing Record 44 of Set 9 | luanda
# Processing Record 45 of Set 9 | manado
# Processing Record 46 of Set 9 | caleta olivia
# Processing Record 47 of Set 9 | fortuna
# Processing Record 48 of Set 9 | kapa'a
# Processing Record 49 of Set 9 | westport
# Processing Record 0 of Set 10 | olinda
# Processing Record 1 of Set 10 | egilsstadir
# Processing Record 2 of Set 10 | vadso
# Processing Record 3 of Set 10 | paradip garh
# Processing Record 4 of Set 10 | ternate
# Processing Record 5 of Set 10 | christchurch
# Processing Record 6 of Set 10 | necochea
# Processing Record 7 of Set 10 | antibes
# Processing Record 8 of Set 10 | bonyhad
# Processing Record 9 of Set 10 | koubia
# Processing Record 10 of Set 10 | dashitou
# Processing Record 11 of Set 10 | kaa-khem
# Processing Record 12 of Set 10 | arkhangel'sk
# Processing Record 13 of Set 10 | gridley
# Processing Record 14 of Set 10 | ilukste
# Processing Record 15 of Set 10 | manta
# Processing Record 16 of Set 10 | noumea
# Processing Record 17 of Set 10 | aligarh
# Processing Record 18 of Set 10 | quezon
# Processing Record 19 of Set 10 | bandarbeyla
# Processing Record 20 of Set 10 | chonchi
# Processing Record 21 of Set 10 | berdigestyakh
# Processing Record 22 of Set 10 | bantogon
# Processing Record 23 of Set 10 | riberalta
# Processing Record 24 of Set 10 | kidal
# Processing Record 25 of Set 10 | manaure
# Processing Record 26 of Set 10 | gaspe
# Processing Record 27 of Set 10 | mainleus
# Processing Record 28 of Set 10 | brisas de zicatela
# Processing Record 29 of Set 10 | dwarka
# Processing Record 30 of Set 10 | inongo
# Processing Record 31 of Set 10 | fairfield glade
# Processing Record 32 of Set 10 | gannan
# Processing Record 33 of Set 10 | smidovich
# Processing Record 34 of Set 10 | kununurra
# Processing Record 35 of Set 10 | grand-bassam
# Processing Record 36 of Set 10 | walvis bay
# Processing Record 37 of Set 10 | castro
# Processing Record 38 of Set 10 | takoradi
# Processing Record 39 of Set 10 | betio village
# Processing Record 40 of Set 10 | pishva
# Processing Record 41 of Set 10 | kingston
# Processing Record 42 of Set 10 | cairns city
# City not found. Skipping...
# Processing Record 43 of Set 10 | lauro de freitas
# Processing Record 44 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 10 | nuku'alofa
# Processing Record 46 of Set 10 | maryborough
# Processing Record 47 of Set 10 | cuatro cienegas de carranza
# Processing Record 48 of Set 10 | pisco
# Processing Record 49 of Set 10 | vila velha
# Processing Record 0 of Set 11 | sarmiento
# Processing Record 1 of Set 11 | tambopata
# Processing Record 2 of Set 11 | jayapura
# Processing Record 3 of Set 11 | banda aceh
# Processing Record 4 of Set 11 | yangchun
# Processing Record 5 of Set 11 | ambon
# Processing Record 6 of Set 11 | acapulco de juarez
# Processing Record 7 of Set 11 | mugia
# Processing Record 8 of Set 11 | altamira
# Processing Record 9 of Set 11 | xining
# Processing Record 10 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 11 of Set 11 | sake
# Processing Record 12 of Set 11 | sonoita
# Processing Record 13 of Set 11 | uusikaupunki
# Processing Record 14 of Set 11 | lerwick
# Processing Record 15 of Set 11 | olyokminsk
# Processing Record 16 of Set 11 | port macquarie
# Processing Record 17 of Set 11 | mata-utu
# Processing Record 18 of Set 11 | kantunilkin
# Processing Record 19 of Set 11 | kisangani
# Processing Record 20 of Set 11 | magadan
# Processing Record 21 of Set 11 | nadi
# Processing Record 22 of Set 11 | kokopo
# Processing Record 23 of Set 11 | aginskoye
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | altentreptow
# Processing Record 26 of Set 11 | praia
# Processing Record 27 of Set 11 | hasaki
# Processing Record 28 of Set 11 | nemuro
# Processing Record 29 of Set 11 | nahariyya
# Processing Record 30 of Set 11 | asau
# Processing Record 31 of Set 11 | ardestan
# Processing Record 32 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 33 of Set 11 | kingsbridge
# Processing Record 34 of Set 11 | tamanrasset
# Processing Record 35 of Set 11 | kargil
# Processing Record 36 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 37 of Set 11 | vyatskiye polyany
# Processing Record 38 of Set 11 | novo aripuana
# Processing Record 39 of Set 11 | orkney
# Processing Record 40 of Set 11 | eyl
# Processing Record 41 of Set 11 | sungai raya
# Processing Record 42 of Set 11 | kovdor
# Processing Record 43 of Set 11 | alo
# Processing Record 44 of Set 11 | ebolowa
# Processing Record 45 of Set 11 | pingliang
# Processing Record 46 of Set 11 | bolivar
# Processing Record 47 of Set 11 | nagqu
# Processing Record 48 of Set 11 | vicuna
# Processing Record 49 of Set 11 | santiago de cao
# Processing Record 0 of Set 12 | kratie
# Processing Record 1 of Set 12 | kataba
# Processing Record 2 of Set 12 | holma
# Processing Record 3 of Set 12 | ngaoundere
# Processing Record 4 of Set 12 | yamba
# Processing Record 5 of Set 12 | tonj
# Processing Record 6 of Set 12 | iquitos
# Processing Record 7 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 8 of Set 12 | cam ranh
# Processing Record 9 of Set 12 | isangel
# Processing Record 10 of Set 12 | forster
# Processing Record 11 of Set 12 | shetpe
# Processing Record 12 of Set 12 | suva
# Processing Record 13 of Set 12 | yatou
# Processing Record 14 of Set 12 | yutsa
# Processing Record 15 of Set 12 | staritsa
# Processing Record 16 of Set 12 | sishui
# Processing Record 17 of Set 12 | guarapari
# Processing Record 18 of Set 12 | tevragh zeina
# City not found. Skipping...
# Processing Record 19 of Set 12 | hluti
# Processing Record 20 of Set 12 | anatuya
# Processing Record 21 of Set 12 | naze
# Processing Record 22 of Set 12 | hillsboro
# Processing Record 23 of Set 12 | strezhevoy
# Processing Record 24 of Set 12 | rehoboth
# Processing Record 25 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 26 of Set 12 | santa ines
# Processing Record 27 of Set 12 | nouadhibou
# Processing Record 28 of Set 12 | ivins
# Processing Record 29 of Set 12 | mavelikara
# Processing Record 30 of Set 12 | yerofey pavlovich
# Processing Record 31 of Set 12 | dauphin
# Processing Record 32 of Set 12 | hafar al-batin
# Processing Record 33 of Set 12 | yangjiang
# Processing Record 34 of Set 12 | holbrook
# Processing Record 35 of Set 12 | abepura
# Processing Record 36 of Set 12 | xifeng
# Processing Record 37 of Set 12 | huarmey
# Processing Record 38 of Set 12 | cabo san lucas
# Processing Record 39 of Set 12 | la libertad
# Processing Record 40 of Set 12 | villa emilio carranza
# Processing Record 41 of Set 12 | samfya
# Processing Record 42 of Set 12 | arar
# Processing Record 43 of Set 12 | willowmore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Export the City_Data into a csv
city_data_df.to_csv("C:/Users/aliso/ucd/gitlab/Python-API-Challenge/Starter_Code/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("C:/Users/aliso/ucd/gitlab/Python-API-Challenge/Starter_Code/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        wailua homesteads  22.0669 -159.3780     70.59        86         100
# 1                 waitangi -43.9535 -176.5597     53.82        89          80
# 2                   bethel  41.3712  -73.4140     46.27        89         100
# 3                  bubaque  11.2833  -15.8333     79.68        54          48
# 4              west island -12.1568   96.8225     84.18        84          75
#
#          Wind Speed Country        Date
# City_ID
# 0              5.75      US  1682674083
# 1             13.51      NZ  1682673994
# 2              3.44      US  1682673982
# 3              2.93      GW  1682674037
# 4              8.05      CC  1682674017

# %%
# Next, you'll create a series of scatter plots to showcase the following relationships:
# Latitude vs. Temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],facecolors ="orange", edgecolors ="black")
plt.title("Latitude vs. Temperature(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("C:/Users/aliso/ucd/gitlab/Python-API-Challenge/Starter_Code/output_data/Fig1.png")
plt.show()

# %%
# Latitude vs. Humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],facecolors ="blue", edgecolors ="black")
plt.title("Latitude vs. Humidity(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("C:/Users/aliso/ucd/gitlab/Python-API-Challenge/Starter_Code/output_data/Fig2.png")
plt.show()

# %%
# Latitude vs. Cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],facecolors ="purple", edgecolors ="black")
plt.title("Latitude vs. Cloudiness(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("C:/Users/aliso/ucd/gitlab/Python-API-Challenge/Starter_Code/output_data/Fig3.png")
plt.show()

# %%
# Latitude vs. Wind Speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],facecolors ="pink", edgecolors ="black")
plt.title("Latitude vs. Wind Speed(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
plt.grid()
plt.savefig("C:/Users/aliso/ucd/gitlab/Python-API-Challenge/Starter_Code/output_data/Fig4.png")
plt.show()

# %% [markdown]
# <h2 style = "font-family:'Arial Narrow';font-size:2.5rem;color:Darkgrey;">Requirement 2: Compute Linear Regression for Each Relationship</h2>

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, x_label="", y_label="", title=""):
    sns.regplot(x=x, y=y)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        wailua homesteads  22.0669 -159.3780     70.59        86         100
# 2                   bethel  41.3712  -73.4140     46.27        89         100
# 3                  bubaque  11.2833  -15.8333     79.68        54          48
# 5               constantia  44.1833   28.6500     57.88        50          99
# 6               fort bragg  35.1390  -79.0060     65.19        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.75      US  1682674083
# 2              3.44      US  1682673982
# 3              2.93      GW  1682674037
# 5             22.59      RO  1682674015
# 6              5.75      US  1682674030

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 waitangi -43.9535 -176.5597     53.82        89          80
# 4              west island -12.1568   96.8225     84.18        84          75
# 9        port-aux-francais -49.3500   70.2167     43.18        69          17
# 12           blackmans bay -43.0167  147.3167     50.74        60         100
# 13               whakatane -37.9585  176.9854     56.52        85         100
#
#          Wind Speed Country        Date
# City_ID
# 1             13.51      NZ  1682673994
# 4              8.05      CC  1682674017
# 9             22.66      TF  1682673998
# 12             7.00      AU  1682674052
# 13             3.00      NZ  1682674334

# %%
# You should create the following plots:
# Northern Hemisphere: Temperature vs. Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

linear_regression_plot(x_values,y_values, "Max Temp", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Southern Hemisphere: Temperature vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

linear_regression_plot(x_values,y_values, "Max Temp", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Northern Hemisphere: Humidity vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

linear_regression_plot(x_values,y_values, "Humidity", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Southern Hemisphere: Humidity vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

linear_regression_plot(x_values,y_values, "Humidity", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Northern Hemisphere: Cloudiness vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

linear_regression_plot(x_values,y_values, "Cloudiness", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Southern Hemisphere: Cloudiness vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

linear_regression_plot(x_values,y_values, "Cloudiness", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Northern Hemisphere: Wind Speed vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

linear_regression_plot(x_values,y_values, "Wind Speed", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943

# %%
# Southern Hemisphere: Wind Speed vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

linear_regression_plot(x_values,y_values, "Wind Speed", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7235555466041943
