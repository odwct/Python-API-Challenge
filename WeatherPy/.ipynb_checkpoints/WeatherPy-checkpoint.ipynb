# %% [markdown]
# <h1 style = "font-family:'Arial Narrow';font-size:4rem;color:darkblue;">Weather Py</h1>

# %% [markdown]
# Python script to visualize the weather of over 500 cities of varying distances from the equator.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import json
from scipy.stats import linregress

# %%
# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# <h2 style = "font-family:'Arial Narrow';font-size:2.5rem;color:Darkgrey;">Generate the Cities List by Using the "citipy" Library</h2>

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# print(json.dumps(cities, indent = 3, sort_keys = True))
# Out:
# Number of cities in the list: 583

# %% [markdown]
# <h2 style = "font-family:'Arial Narrow';font-size:2.5rem;color:Darkgrey;">Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude</h2>

# %%
# To fulfill the first requirement, you'll use the OpenWeatherMap API to retrieve weather data from the cities list generated in the starter code. 

# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Create endpoint URL with each city
    city_url = url +  city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() 

       # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | el bolson
# Processing Record 4 of Set 1 | port mathurin
# Processing Record 5 of Set 1 | umm kaddadah
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | puerto natales
# Processing Record 8 of Set 1 | iskateley
# Processing Record 9 of Set 1 | bandar lampung
# Processing Record 10 of Set 1 | vadso
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | fale old settlement
# Processing Record 13 of Set 1 | atafu village
# Processing Record 14 of Set 1 | uturoa
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | pangody
# Processing Record 17 of Set 1 | udachny
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 20 of Set 1 | west island
# Processing Record 21 of Set 1 | kaa-khem
# Processing Record 22 of Set 1 | qaqortoq
# Processing Record 23 of Set 1 | invercargill
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | aasiaat
# Processing Record 28 of Set 1 | bure
# Processing Record 29 of Set 1 | port-aux-francais
# Processing Record 30 of Set 1 | bilibino
# Processing Record 31 of Set 1 | probolinggo
# Processing Record 32 of Set 1 | lodja
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | kindu
# Processing Record 35 of Set 1 | constantia
# Processing Record 36 of Set 1 | stanley
# Processing Record 37 of Set 1 | buka
# Processing Record 38 of Set 1 | mo i rana
# Processing Record 39 of Set 1 | kapuskasing
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | san antonio de pale
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | utrik
# Processing Record 45 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 46 of Set 1 | whitehorse
# Processing Record 47 of Set 1 | badger
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | lihue
# Processing Record 50 of Set 1 | machico
# Processing Record 0 of Set 2 | poquoson
# Processing Record 1 of Set 2 | serenje
# Processing Record 2 of Set 2 | st. john's
# Processing Record 3 of Set 2 | ust-nera
# Processing Record 4 of Set 2 | grytviken
# Processing Record 5 of Set 2 | al majaridah
# Processing Record 6 of Set 2 | inekar
# City not found. Skipping...
# Processing Record 7 of Set 2 | hawaiian paradise park
# Processing Record 8 of Set 2 | dryden
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | loango
# Processing Record 11 of Set 2 | san juan de miraflores
# Processing Record 12 of Set 2 | carutapera
# Processing Record 13 of Set 2 | kargasok
# Processing Record 14 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 2 | santa marta
# Processing Record 16 of Set 2 | saint-francois
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | la foa
# Processing Record 19 of Set 2 | manuel ojinaga
# City not found. Skipping...
# Processing Record 20 of Set 2 | oriximina
# Processing Record 21 of Set 2 | boa vista
# Processing Record 22 of Set 2 | nizao
# Processing Record 23 of Set 2 | alice springs
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | guatire
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | entebbe
# Processing Record 9 of Set 4 | burang
# Processing Record 10 of Set 4 | arawa
# Processing Record 11 of Set 4 | podgornaya
# Processing Record 12 of Set 4 | gadzhiyevo
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | burabay
# Processing Record 15 of Set 4 | springbok
# Processing Record 16 of Set 4 | aktobe
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | vilyuchinsk
# Processing Record 19 of Set 4 | beyneu
# Processing Record 20 of Set 4 | malpe
# Processing Record 21 of Set 4 | manismata
# Processing Record 22 of Set 4 | khandyga
# Processing Record 23 of Set 4 | bamboo flat
# Processing Record 24 of Set 4 | lerwick
# Processing Record 25 of Set 4 | garoowe
# Processing Record 26 of Set 4 | mozhga
# Processing Record 27 of Set 4 | blackmans bay
# Processing Record 28 of Set 4 | cuamba
# Processing Record 29 of Set 4 | talcahuano
# Processing Record 30 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 31 of Set 4 | kristiansund
# Processing Record 32 of Set 4 | kangiwa
# Processing Record 33 of Set 4 | margate
# Processing Record 34 of Set 4 | merizo village
# Processing Record 35 of Set 4 | dudinka
# Processing Record 36 of Set 4 | cole harbour
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | al qadarif
# Processing Record 39 of Set 4 | asan-maina village
# Processing Record 40 of Set 4 | san andres
# Processing Record 41 of Set 4 | fort bragg
# Processing Record 42 of Set 4 | karangampel
# Processing Record 43 of Set 4 | tirlyanskiy
# Processing Record 44 of Set 4 | tazacorte
# Processing Record 45 of Set 4 | romita
# Processing Record 46 of Set 4 | ramganj mandi
# Processing Record 47 of Set 4 | ribeira brava
# Processing Record 48 of Set 4 | mirpur mathelo
# Processing Record 49 of Set 4 | byron bay
# Processing Record 0 of Set 5 | santiago de cao
# Processing Record 1 of Set 5 | nkove
# Processing Record 2 of Set 5 | hadibu
# Processing Record 3 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 4 of Set 5 | cururupu
# Processing Record 5 of Set 5 | little falls
# Processing Record 6 of Set 5 | riyadh
# Processing Record 7 of Set 5 | san jose del guaviare
# Processing Record 8 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | kunming
# Processing Record 11 of Set 5 | crane
# Processing Record 12 of Set 5 | cumberland
# Processing Record 13 of Set 5 | iwanai
# Processing Record 14 of Set 5 | la passe
# Processing Record 15 of Set 5 | tromso
# Processing Record 16 of Set 5 | aykhal
# Processing Record 17 of Set 5 | inari
# Processing Record 18 of Set 5 | natal
# Processing Record 19 of Set 5 | dakhla
# Processing Record 20 of Set 5 | hermanus
# Processing Record 21 of Set 5 | tolanaro
# Processing Record 22 of Set 5 | susuman
# Processing Record 23 of Set 5 | general villegas
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | tamanrasset
# Processing Record 26 of Set 5 | dongkan
# Processing Record 27 of Set 5 | vernon
# Processing Record 28 of Set 5 | moog
# Processing Record 29 of Set 5 | tazovsky
# Processing Record 30 of Set 5 | telerghma
# Processing Record 31 of Set 5 | freetown
# Processing Record 32 of Set 5 | mil'kovo
# Processing Record 33 of Set 5 | harper
# Processing Record 34 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 5 | clifton
# Processing Record 36 of Set 5 | nurabad
# Processing Record 37 of Set 5 | huarmey
# Processing Record 38 of Set 5 | likiep
# Processing Record 39 of Set 5 | nueva gerona
# Processing Record 40 of Set 5 | meybod
# Processing Record 41 of Set 5 | da nang
# Processing Record 42 of Set 5 | little cayman
# City not found. Skipping...
# Processing Record 43 of Set 5 | nova vicosa
# Processing Record 44 of Set 5 | rayside-balfour
# City not found. Skipping...
# Processing Record 45 of Set 5 | trancas
# Processing Record 46 of Set 5 | mata-utu
# Processing Record 47 of Set 5 | kone
# Processing Record 48 of Set 5 | bulanik
# Processing Record 49 of Set 5 | novodvinsk
# Processing Record 0 of Set 6 | emerald
# Processing Record 1 of Set 6 | remire-montjoly
# Processing Record 2 of Set 6 | vohipaho
# City not found. Skipping...
# Processing Record 3 of Set 6 | ghadamis
# Processing Record 4 of Set 6 | puerto baquerizo moreno
# Processing Record 5 of Set 6 | taksimo
# Processing Record 6 of Set 6 | yavatmal
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | burkardroth
# Processing Record 9 of Set 6 | arifwala
# Processing Record 10 of Set 6 | cochin
# Processing Record 11 of Set 6 | pasighat
# Processing Record 12 of Set 6 | kuta
# Processing Record 13 of Set 6 | pointe-noire
# Processing Record 14 of Set 6 | sandnessjoen
# Processing Record 15 of Set 6 | posto fiscal rolim de moura
# Processing Record 16 of Set 6 | celestun
# Processing Record 17 of Set 6 | nova sintra
# Processing Record 18 of Set 6 | taulaga
# Processing Record 19 of Set 6 | eyl
# Processing Record 20 of Set 6 | fort st. john
# Processing Record 21 of Set 6 | maumere
# Processing Record 22 of Set 6 | al jubayl
# Processing Record 23 of Set 6 | kailua-kona
# Processing Record 24 of Set 6 | hithadhoo
# Processing Record 25 of Set 6 | shakawe
# Processing Record 26 of Set 6 | holmestrand
# Processing Record 27 of Set 6 | nanpiao
# Processing Record 28 of Set 6 | pruzhany
# Processing Record 29 of Set 6 | cockburn town
# Processing Record 30 of Set 6 | tabas
# Processing Record 31 of Set 6 | cassilandia
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | porto santo stefano
# Processing Record 34 of Set 6 | shangqiu
# Processing Record 35 of Set 6 | tiszakecske
# Processing Record 36 of Set 6 | east london
# Processing Record 37 of Set 6 | khorixas
# Processing Record 38 of Set 6 | haiku-pauwela
# Processing Record 39 of Set 6 | linares
# Processing Record 40 of Set 6 | belle fourche
# Processing Record 41 of Set 6 | alta sierra
# Processing Record 42 of Set 6 | puerto lopez
# Processing Record 43 of Set 6 | mukalla
# Processing Record 44 of Set 6 | pawayan
# Processing Record 45 of Set 6 | enewetak
# Processing Record 46 of Set 6 | selebi-phikwe
# Processing Record 47 of Set 6 | galle
# Processing Record 48 of Set 6 | waterloo
# Processing Record 49 of Set 6 | morehead city
# Processing Record 0 of Set 7 | tindouf
# Processing Record 1 of Set 7 | kudahuvadhoo
# Processing Record 2 of Set 7 | gaigeturi
# Processing Record 3 of Set 7 | port augusta
# Processing Record 4 of Set 7 | palmas
# Processing Record 5 of Set 7 | kingston
# Processing Record 6 of Set 7 | kidal
# Processing Record 7 of Set 7 | mount pearl
# Processing Record 8 of Set 7 | iguape
# Processing Record 9 of Set 7 | ratnagiri
of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 8 | soledade
# Processing Record 41 of Set 8 | castillos
# Processing Record 42 of Set 8 | tarhuna
# Processing Record 43 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 44 of Set 8 | pyay
# Processing Record 45 of Set 8 | damghan
# Processing Record 46 of Set 8 | la'ie
# Processing Record 47 of Set 8 | melilla
# Processing Record 48 of Set 8 | gates-north gates
# City not found. Skipping...
# Processing Record 49 of Set 8 | parlakimidi
# Processing Record 0 of Set 9 | les avirons
# Processing Record 1 of Set 9 | prince george
# Processing Record 2 of Set 9 | curup
# Processing Record 3 of Set 9 | puerto quijarro
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | nemuro
# Processing Record 6 of Set 9 | kerikeri
# Processing Record 7 of Set 9 | karkira
# Processing Record 8 of Set 9 | grand baie
# Processing Record 9 of Set 9 | albertina
# Processing Record 10 of Set 9 | aykol
# City not found. Skipping...
# Processing Record 11 of Set 9 | laguna
# Processing Record 12 of Set 9 | cill airne
# Processing Record 13 of Set 9 | whyalla stuart
# City not found. Skipping...
# Processing Record 14 of Set 9 | tambura
# Processing Record 15 of Set 9 | midvagur
# Processing Record 16 of Set 9 | thinadhoo
# Processing Record 17 of Set 9 | pak chong
# Processing Record 18 of Set 9 | shache
# Processing Record 19 of Set 9 | kropachevo
# Processing Record 20 of Set 9 | bikenibeu village
# Processing Record 21 of Set 9 | marvdasht
# City not found. Skipping...
# Processing Record 22 of Set 9 | lubao
# Processing Record 23 of Set 9 | brookings
# Processing Record 24 of Set 9 | grande prairie
# Processing Record 25 of Set 9 | pilibangan
# Processing Record 26 of Set 9 | roma
# Processing Record 27 of Set 9 | keetmanshoop
# Processing Record 28 of Set 9 | shiyan
# Processing Record 29 of Set 9 | paciran
# Processing Record 30 of Set 9 | zhigalovo
# Processing Record 31 of Set 9 | kisangani
# Processing Record 32 of Set 9 | port blair
# Processing Record 33 of Set 9 | ad dabbah
# Processing Record 34 of Set 9 | zhuangyuan
# Processing Record 35 of Set 9 | sarakhs
# Processing Record 36 of Set 9 | kharp
# Processing Record 37 of Set 9 | shiguai
# Processing Record 38 of Set 9 | arenapolis
# Processing Record 39 of Set 9 | chake chake
# Processing Record 40 of Set 9 | arkhangel'sk
# Processing Record 41 of Set 9 | nantucket
# Processing Record 42 of Set 9 | masterton
# Processing Record 43 of Set 9 | zangguy
# City not found. Skipping...
# Processing Record 44 of Set 9 | fuglafjordur
# Processing Record 45 of Set 9 | joshimath
# Processing Record 46 of Set 9 | tralee
# Processing Record 47 of Set 9 | bubaque
# Processing Record 48 of Set 9 | barcelos
# Processing Record 49 of Set 9 | monrovia
# Processing Record 0 of Set 10 | lagunas
# Processing Record 1 of Set 10 | fontanelas
# Processing Record 2 of Set 10 | cincinnati
# Processing Record 3 of Set 10 | howrah
# Processing Record 4 of Set 10 | petauke
# Processing Record 5 of Set 10 | georgiyevka
# Processing Record 6 of Set 10 | lethem
# Processing Record 7 of Set 10 | brisas de zicatela
# Processing Record 8 of Set 10 | kismayo
# Processing Record 9 of Set 10 | dunedin
# Processing Record 10 of Set 10 | ust'-ilimsk
# Processing Record 11 of Set 10 | luoyang
# Processing Record 12 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 10 | isangel
# Processing Record 14 of Set 10 | diplo
# Processing Record 15 of Set 10 | trinity beach
# Processing Record 16 of Set 10 | mabai
# Processing Record 17 of Set 10 | akrehamn
# Processing Record 18 of Set 10 | mar del plata
# Processing Record 19 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 20 of Set 10 | filadelfia
# Processing Record 21 of Set 10 | vorgashor
# Processing Record 22 of Set 10 | verdal
# Processing Record 23 of Set 10 | lukolela
# Processing Record 24 of Set 10 | segou
# Processing Record 25 of Set 10 | padua
# Processing Record 26 of Set 10 | hailar
# Processing Record 27 of Set 10 | honiara
# Processing Record 28 of Set 10 | chinde
# Processing Record 29 of Set 10 | jatai
# Processing Record 30 of Set 10 | davyd-haradok
# Processing Record 31 of Set 10 | chongwe
# Processing Record 32 of Set 10 | matoury
# Processing Record 33 of Set 10 | almenara
# Processing Record 34 of Set 10 | nabire
# Processing Record 35 of Set 10 | vila franca do campo
# Processing Record 36 of Set 10 | polyarnyy
# Processing Record 37 of Set 10 | ponta delgada
# Processing Record 38 of Set 10 | mount gambier
# Processing Record 39 of Set 10 | bac lieu
# Processing Record 40 of Set 10 | sakaiminato
# Processing Record 41 of Set 10 | tyre
# Processing Record 42 of Set 10 | bargara
# City not found. Skipping...
# Processing Record 43 of Set 10 | puerto maldonado
# Processing Record 44 of Set 10 | argostolion
# Processing Record 45 of Set 10 | monett
# Processing Record 46 of Set 10 | fortaleza
# Processing Record 47 of Set 10 | wang saphung
# Processing Record 48 of Set 10 | ghat
# Processing Record 49 of Set 10 | poronaysk
# Processing Record 0 of Set 11 | coronel dorrego
# Processing Record 1 of Set 11 | gornozavodsk
# Processing Record 2 of Set 11 | chernyshevskiy
# Processing Record 3 of Set 11 | nha trang
# Processing Record 4 of Set 11 | vilyuysk
# Processing Record 5 of Set 11 | san lorenzo
# Processing Record 6 of Set 11 | stephenville
# Processing Record 7 of Set 11 | colon
# Processing Record 8 of Set 11 | nieuw amsterdam
# Processing Record 9 of Set 11 | guerrero negro
# Processing Record 10 of Set 11 | malvan
# Processing Record 11 of Set 11 | ocean pointe
# City not found. Skipping...
# Processing Record 12 of Set 11 | al khums
# Processing Record 13 of Set 11 | mariental
# Processing Record 14 of Set 11 | goseong
# Processing Record 15 of Set 11 | gavle
# Processing Record 16 of Set 11 | canutama
# Processing Record 17 of Set 11 | hamilton
# Processing Record 18 of Set 11 | ain sukhna
# Processing Record 19 of Set 11 | tamuin
# Processing Record 20 of Set 11 | mossel bay
# Processing Record 21 of Set 11 | ust-tsilma
# Processing Record 22 of Set 11 | yakeshi
# Processing Record 23 of Set 11 | langepas
# Processing Record 24 of Set 11 | lencois paulista
# Processing Record 25 of Set 11 | luanda
# Processing Record 26 of Set 11 | northam
# Processing Record 27 of Set 11 | ixtapa
# Processing Record 28 of Set 11 | tezu
# Processing Record 29 of Set 11 | bridgewater
# Processing Record 30 of Set 11 | bardai
# Processing Record 31 of Set 11 | aljezur
# Processing Record 32 of Set 11 | shelton
# Processing Record 33 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 34 of Set 11 | leava
# Processing Record 35 of Set 11 | cadale
# Processing Record 36 of Set 11 | guiria
# City not found. Skipping...
# Processing Record 37 of Set 11 | malakal
# Processing Record 38 of Set 11 | santarem
# Processing Record 39 of Set 11 | hammerfest
# Processing Record 40 of Set 11 | carolina beach
# Processing Record 41 of Set 11 | benxi
# Processing Record 42 of Set 11 | laojunmiao
# Processing Record 43 of Set 11 | reidsville
# Processing Record 44 of Set 11 | tyuratam
# Processing Record 45 of Set 11 | mersa matruh
# Processing Record 46 of Set 11 | gao
# Processing Record 47 of Set 11 | dadukou
# Processing Record 48 of Set 11 | suntar
# Processing Record 49 of Set 11 | mezgor'e
# City not found. Skipping...
# Processing Record 0 of Set 12 | karratha
# Processing Record 1 of Set 12 | malango
# Processing Record 2 of Set 12 | cairns city
# City not found. Skipping...
# Processing Record 3 of Set 12 | port isabel
# Processing Record 4 of Set 12 | happy valley-goose bay
# Processing Record 5 of Set 12 | narvik
# Processing Record 6 of Set 12 | karabar
# Processing Record 7 of Set 12 | ulsteinvik
# Processing Record 8 of Set 12 | callao
# Processing Record 9 of Set 12 | broken hill
# Processing Record 10 of Set 12 | antalaha
# Processing Record 11 of Set 12 | hosdurga
# Processing Record 12 of Set 12 | itoman
# Processing Record 13 of Set 12 | cuito
# Processing Record 14 of Set 12 | altinekin
# Processing Record 15 of Set 12 | vershino-darasunskiy
# Processing Record 16 of Set 12 | solnechnyy
# Processing Record 17 of Set 12 | vila do maio
# Processing Record 18 of Set 12 | lobujya
# Processing Record 19 of Set 12 | fukuecho
# Processing Record 20 of Set 12 | lazaro cardenas
# Processing Record 21 of Set 12 | blythe
# Processing Record 22 of Set 12 | kiunga
# Processing Record 23 of Set 12 | eket
# Processing Record 24 of Set 12 | taquaritinga do norte
# Processing Record 25 of Set 12 | menongue
# Processing Record 26 of Set 12 | praia da vitoria
# Processing Record 27 of Set 12 | skovorodino
# Processing Record 28 of Set 12 | gizo
# Processing Record 29 of Set 12 | stornoway
# Processing Record 30 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 31 of Set 12 | kapa'a
# Processing Record 32 of Set 12 | komsomol'skiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          548
# Lat           548
# Lng           548
# Max Temp      548
# Humidity      548
# Cloudiness    548
# Wind Speed    548
# Country       548
# Date          548
# dtype: int64

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             waitangi -43.9535 -176.5597     56.82        90          43
# 1            jamestown  42.0970  -79.2353     65.84        19           0
# 2            el bolson -41.9667  -71.5167     53.42        90          92
# 3        port mathurin -19.6833   63.4167     77.92        75          31
# 4         umm kaddadah  13.6017   26.6876     85.42        10           1
#
#          Wind Speed Country        Date
# City_ID
# 0              7.00      NZ  1684188119
# 1              9.22      US  1684188120
# 2              4.88      AR  1684188050
# 3             16.67      MU  1684188121
# 4              9.69      SD  1684188121

# %%
# Next, you'll create a series of scatter plots to showcase the following relationships:
# Latitude vs. Temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],facecolors ="orange", edgecolors ="black")
plt.title("Latitude vs. Temperature(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("../output_data/Fig1.png")
plt.show()

# %%
# Latitude vs. Humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],facecolors ="blue", edgecolors ="black")
plt.title("Latitude vs. Humidity(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../output_data/Fig2.png")
plt.show()

# %%
# Latitude vs. Cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],facecolors ="purple", edgecolors ="black")
plt.title("Latitude vs. Cloudiness(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("../output_data/Fig3.png")
plt.show()

# %%
# Latitude vs. Wind Speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],facecolors ="pink", edgecolors ="black")
plt.title("Latitude vs. Wind Speed(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
plt.grid()
plt.savefig("../output_data/Fig4.png")
plt.show()

# %% [markdown]
# <h2 style = "font-family:'Arial Narrow';font-size:2.5rem;color:Darkgrey;">Requirement 2: Compute Linear Regression for Each Relationship</h2>

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, x_label="", y_label="", title=""):
    sns.regplot(x=x, y=y)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           jamestown  42.0970 -79.2353     65.84        19           0
# 4        umm kaddadah  13.6017  26.6876     85.42        10           1
# 5            thompson  55.7435 -97.8558     69.96        40          40
# 7           iskateley  67.6803  53.1512     31.87        98          75
# 9               vadso  70.0744  29.7487     58.08        81           0
#
#          Wind Speed Country        Date
# City_ID
# 1              9.22      US  1684188120
# 4              9.69      SD  1684188121
# 5             23.02      CA  1684188108
# 7              4.36      RU  1684188124
# 9             13.80      NO  1684188125

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              waitangi -43.9535 -176.5597     56.82        90          43
# 2             el bolson -41.9667  -71.5167     53.42        90          92
# 3         port mathurin -19.6833   63.4167     77.92        75          31
# 6        puerto natales -51.7236  -72.4875     42.48        93          96
# 8        bandar lampung  -5.4254  105.2580     75.13        94          57
#
#          Wind Speed Country        Date
# City_ID
# 0              7.00      NZ  1684188119
# 2              4.88      AR  1684188050
# 3             16.67      MU  1684188121
# 6              4.45      CL  1684188123
# 8              4.14      ID  1684188125

# %%
# You should create the following plots:
# Northern Hemisphere: Temperature vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Max Temp", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Northern Hemisphere: Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6313612301790738

# %%
# Southern Hemisphere: Temperature vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Max Temp", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Southern Hemisphere: Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7280956075806279

# %%
# Northern Hemisphere: Humidity vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Humidity", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Northern Hemisphere: Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0004284597051098346

# %%
# Southern Hemisphere: Humidity vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Humidity", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Southern Hemisphere: Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.016795741315576738

# %%
# Northern Hemisphere: Cloudiness vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Cloudiness", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Northern Hemisphere: Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 4.5343467269006065e-07

# %%
# Southern Hemisphere: Cloudiness vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Cloudiness", (1,10))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Southern Hemisphere: Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.016812801310072296

# %%
# Northern Hemisphere: Wind Speed vs. Latitude

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Wind Speed", (40,60))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Northern Hemisphere: Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00062732871561688

# %%
# Southern Hemisphere: Wind Speed vs. Latitude

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

linear_regression_plot(x_values,y_values, "Wind Speed", (70,80))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("Southern Hemisphere: Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04803154158646407
